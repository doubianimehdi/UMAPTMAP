# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import umap
import umap.plot
import sklearn.cluster as cluster
from sklearn.metrics import adjusted_rand_score, adjusted_mutual_info_score

# %%
from matplotlib import rcParams

# figure size in inches
rcParams['figure.figsize'] = 10,10

# %%
#Creating dataframe for data.
data = pd.read_csv('C:\OpenClassRooms\projet 7\gene-expression-cancer-rnaseq\data.csv', delimiter=',',index_col=0)
nRow, nCol = data.shape
print(f'There are {nRow} rows and {nCol} columns in data.')
# Out:
# There are 801 rows and 20531 columns in data.

# %%
#Inspect first 5 rows of data.
data.head(5)
# Out:
#           gene_0    gene_1    gene_2    gene_3     gene_4  gene_5    gene_6  \
# sample_0     0.0  2.017209  3.265527  5.478487  10.431999     0.0  7.175175
# sample_1     0.0  0.592732  1.588421  7.586157   9.623011     0.0  6.816049
# sample_2     0.0  3.511759  4.327199  6.881787   9.870730     0.0  6.972130
# sample_3     0.0  3.663618  4.507649  6.659068  10.196184     0.0  7.843375
# sample_4     0.0  2.655741  2.821547  6.539454   9.738265     0.0  6.566967
#
#             gene_7  gene_8  gene_9  ...  gene_20521  gene_20522  gene_20523  \
# sample_0  0.591871     0.0     0.0  ...    4.926711    8.210257    9.723516
# sample_1  0.000000     0.0     0.0  ...    4.593372    7.323865    9.740931
# sample_2  0.452595     0.0     0.0  ...    5.125213    8.127123   10.908640
# sample_3  0.434882     0.0     0.0  ...    6.076566    8.792959   10.141520
# sample_4  0.360982     0.0     0.0  ...    5.996032    8.891425   10.373790
#
#           gene_20524  gene_20525  gene_20526  gene_20527  gene_20528  \
# sample_0    7.220030    9.119813   12.003135    9.650743    8.921326
# sample_1    6.256586    8.381612   12.674552   10.517059    9.397854
# sample_2    5.401607    9.911597    9.045255    9.788359   10.090470
# sample_3    8.942805    9.601208   11.392682    9.694814    9.684365
# sample_4    7.181162    9.846910   11.922439    9.217749    9.461191
#
#           gene_20529  gene_20530
# sample_0    5.286759         0.0
# sample_1    2.094168         0.0
# sample_2    1.683023         0.0
# sample_3    3.292001         0.0
# sample_4    5.110372         0.0
#
# [5 rows x 20531 columns]

# %%
#Creating dataframe for labels.
labels = pd.read_csv('C:\OpenClassRooms\projet 7\gene-expression-cancer-rnaseq\labels.csv', delimiter=',')
nRow, nCol = labels.shape
print(f'There are {nRow} rows and {nCol} columns in labels dataframe.')
# Out:
# There are 801 rows and 2 columns in labels dataframe.

# %%
#Inspect first 5 rows of labels.
labels.head(5)
# Out:
#   Unnamed: 0 Class
# 0   sample_0  PRAD
# 1   sample_1  LUAD
# 2   sample_2  PRAD
# 3   sample_3  PRAD
# 4   sample_4  BRCA

# %%
#Find unique classes of cancer subtypes.
labels['Class'].unique()
# Out:
# array(['PRAD', 'LUAD', 'BRCA', 'KIRC', 'COAD'], dtype=object)

# %%
#Create a 2D numpy array of values in data.
X = data.values
X[0:5]
# Out:
# array([[ 0.        ,  2.01720929,  3.26552691, ...,  8.92132623,
#          5.28675919,  0.        ],
#        [ 0.        ,  0.59273209,  1.58842082, ...,  9.39785429,
#          2.09416849,  0.        ],
#        [ 0.        ,  3.51175898,  4.32719872, ..., 10.09046974,
#          1.68302267,  0.        ],
#        [ 0.        ,  3.66361787,  4.50764878, ...,  9.68436467,
#          3.29200131,  0.        ],
#        [ 0.        ,  2.65574107,  2.82154696, ...,  9.46119088,
#          5.1103716 ,  0.        ]])

# %%
#Standardize the features before performing dimensionality reduction, (mean=0,standard deviation =1)
X_std = StandardScaler().fit_transform(X)

# %%
#Visualize data using Principal Component Analysis.
print("Principal Component Analysis (PCA)")
pca = PCA(n_components = 2).fit_transform(X_std)
pca_df = pd.DataFrame(data=pca, columns=['PC1','PC2']).join(labels)
palette = sns.color_palette("muted", n_colors=5)
sns.set_style("white")
sns.scatterplot(x='PC1',y='PC2',hue='Class',data=pca_df, palette=palette, linewidth=0.2, s=30, alpha=1).set_title('PCA')
# Out:
# Principal Component Analysis (PCA)
# Text(0.5, 1.0, 'PCA')

# %%
#Fitting PCA on Data
print("Explained Variance of PCA components")
pca_std = PCA().fit(X_std)
percent_variance=pca_std.explained_variance_ratio_*100

#Plotting Cumulative Summation of the Explained Variance
plt.figure()
plt.plot(np.cumsum(pca_std.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Variance (%)') #for each component
plt.title('Cancer Dataset - Cumulative Explained Variance')
plt.show()
# Out:
# Explained Variance of PCA components

# %%
#Visualize data using t-SNE.
print("t-Distributed Stochastic Neighbor Embedding (tSNE)")
model = TSNE(learning_rate = 10, n_components = 2, random_state=123, perplexity = 30)
tsne = model.fit_transform(X_std)
tsne_df = pd.DataFrame(data=tsne, columns=['t-SNE1','t-SNE2']).join(labels)
palette = sns.color_palette("muted", n_colors=5)
sns.set_style("white")
sns.scatterplot(x='t-SNE1',y='t-SNE2',hue='Class',data=tsne_df, palette=palette, linewidth=0.2, s=30, alpha=1).set_title('t-SNE')
# Out:
# t-Distributed Stochastic Neighbor Embedding (tSNE)
# Text(0.5, 1.0, 't-SNE')

# %%
#Measure execution time for t-SNE
def tsne_model(X):
    model = TSNE(learning_rate = 10, n_components = 2, random_state = 123, perplexity = 30)
    tsne = model.fit_transform(X)
    return tsne
from timeit import Timer
  
t = Timer(lambda: tsne_model(X_std))
print(t.timeit(number=1))
# Out:
# 19.578304099999997

# %%
#Visualize data using t-SNE after PCA.
print("t-Distributed Stochastic Neighbor Embedding (tSNE) on PCA")
X_reduced = PCA(n_components =100 ).fit_transform(X_std)
model = TSNE(learning_rate = 10, n_components = 2, random_state = 123, perplexity = 30)
tsne_pca = model.fit_transform(X_reduced)
tsne_pca_df = pd.DataFrame(data=tsne_pca, columns=['t-SNE1','t-SNE2']).join(labels)
palette = sns.color_palette("muted", n_colors=5)
sns.set_style("white")
sns.scatterplot(x='t-SNE1',y='t-SNE2',hue='Class',data=tsne_pca_df, palette=palette, linewidth=0.2, s=30, alpha=1).set_title('t-SNE after PCA')
# Out:
# t-Distributed Stochastic Neighbor Embedding (tSNE) on PCA
# Text(0.5, 1.0, 't-SNE after PCA')

# %%
#Measure execution time for t-SNE after PCA
def tsne_model_pca(X):
    X_reduced = PCA(n_components =50 ).fit_transform(X)
    model = TSNE(learning_rate = 10, n_components = 2, random_state = 123, perplexity = 30)
    tsne_pca = model.fit_transform(X_reduced)
    return tsne_pca
from timeit import Timer
  
t = Timer(lambda: tsne_model_pca(X_std))
print(t.timeit(number=1))
# Out:
# 3.0648139000000043

# %%
#Visualize data using UMAP.
print("Uniform Manifold Approximation and Projection (UMAP)")
model = umap.UMAP(n_neighbors = 40, min_dist = 0.4, n_components = 2)
umapper = model.fit_transform(X_std)
umap_df = pd.DataFrame(data=umapper, columns=['UMAP1','UMAP2']).join(labels)
palette = sns.color_palette("muted", n_colors=5)
sns.set_style("white")
sns.scatterplot(x='UMAP1',y='UMAP2',hue='Class',data=umap_df, palette=palette, linewidth=0.2, s=30, alpha=1).set_title('UMAP')
# Out:
# Uniform Manifold Approximation and Projection (UMAP)
# C:\ProgramData\Anaconda3\envs\virtEnv\lib\site-packages\numba\np\ufunc\parallel.py:355: NumbaWarning: The TBB threading layer requires TBB version 2019.5 or later i.e., TBB_INTERFACE_VERSION >= 11005. Found TBB_INTERFACE_VERSION = 11000. The TBB threading layer is disabled.
#   warnings.warn(problem)
# Text(0.5, 1.0, 'UMAP')

# %%
umap_df
# Out:
#          UMAP1     UMAP2  Unnamed: 0 Class
# 0     9.150931 -2.473849    sample_0  PRAD
# 1     9.737071  4.718579    sample_1  LUAD
# 2     7.132878 -3.227772    sample_2  PRAD
# 3     7.460815 -3.093468    sample_3  PRAD
# 4    13.726606  7.577513    sample_4  BRCA
# ..         ...       ...         ...   ...
# 796  13.891920  7.212472  sample_796  BRCA
# 797   8.720440  2.952967  sample_797  LUAD
# 798   8.550143  5.764901  sample_798  COAD
# 799   8.383553 -2.390409  sample_799  PRAD
# 800   7.625867 -2.152717  sample_800  PRAD
#
# [801 rows x 4 columns]

# %%
mapper = umap.UMAP().fit(X)
umap.plot.points(mapper ,labels=umap_df.Class)

# %%
umap.plot.points(mapper ,labels=umap_df.Class, theme='darkred')

# %%
umap.plot.points(mapper, values=umap_df.mean(axis=1), theme='fire')

# %%
umap.plot.points(mapper, labels=umap_df.Class, color_key_cmap='Paired', background='black')

# %%
umap.plot.connectivity(mapper, edge_bundling='hammer')
# Out:
# C:\ProgramData\Anaconda3\envs\virtEnv\lib\site-packages\umap\plot.py:848: UserWarning: Hammer edge bundling is expensive for large graphs!
# This may take a long time to compute!
#   "Hammer edge bundling is expensive for large graphs!\n"
# C:\ProgramData\Anaconda3\envs\virtEnv\lib\site-packages\datashader\bundling.py:36: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function resample_segment failed at nopython mode lowering due to:
#
# File "..\..\ProgramData\Anaconda3\envs\virtEnv\lib\site-packages\datashader\bundling.py", line 55:
# def resample_segment(segments, new_segments, min_segment_length, max_segment_length, ndims):
#     <source elided>
#             for i in range(points):
#                 new_segments[pos] = current_point + (i * ((next_point - current_point) / points))
#                 ^
#
# [1] During: lowering "$208binary_add.10 = arrayexpr(expr=(<built-in function add>, [Var(current_point_6, bundling.py:54), (<built-in function mul>, [Var(i, bundling.py:54), (<built-in function truediv>, [(<built-in function sub>, [Var(next_point.2, bundling.py:54), Var(current_point.6, bundling.py:54)]), Var(points, bundling.py:53)])])]), ty=array(float64, 1d, C))" at C:\ProgramData\Anaconda3\envs\virtEnv\lib\site-packages\datashader\bundling.py (55)
#   @nb.jit
# C:\ProgramData\Anaconda3\envs\virtEnv\lib\site-packages\datashader\bundling.py:36: NumbaWarning:
# Compilation is falling back to object mode WITHOUT looplifting enabled because Function "resample_segment" failed type inference due to: cannot determine Numba type of <class 'numba.core.dispatcher.LiftedLoop'>
#
# File "..\..\ProgramData\Anaconda3\envs\virtEnv\lib\site-packages\datashader\bundling.py", line 42:
# def resample_segment(segments, new_segments, min_segment_length, max_segment_length, ndims):
#     <source elided>
#     index = 1
#     while index < len(segments):
#     ^
#
#   @nb.jit
# C:\ProgramData\Anaconda3\envs\virtEnv\lib\site-packages\numba\core\object_mode_passes.py:178: NumbaWarning: Function "resample_segment" was compiled in object mode without forceobj=True, but has lifted loops.
#
# File "..\..\ProgramData\Anaconda3\envs\virtEnv\lib\site-packages\datashader\bundling.py", line 38:
# def resample_segment(segments, new_segments, min_segment_length, max_segment_length, ndims):
#     next_point = np.zeros(ndims, dtype=segments.dtype)
#     ^
#
#   state.func_ir.loc))
# C:\ProgramData\Anaconda3\envs\virtEnv\lib\site-packages\numba\core\object_mode_passes.py:188: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected, this is deprecated behaviour.
#
# For more information visit http://numba.pydata.org/numba-doc/latest/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "..\..\ProgramData\Anaconda3\envs\virtEnv\lib\site-packages\datashader\bundling.py", line 38:
# def resample_segment(segments, new_segments, min_segment_length, max_segment_length, ndims):
#     next_point = np.zeros(ndims, dtype=segments.dtype)
#     ^
#
#   state.func_ir.loc))

# %%
umap.plot.connectivity(mapper, show_points=True)

# %%
umap.plot.diagnostic(mapper, diagnostic_type='pca')

# %%
umap.plot.diagnostic(mapper, diagnostic_type='local_dim')

# %%
umap.plot.diagnostic(mapper, diagnostic_type='neighborhood')
# Out:
# C:\ProgramData\Anaconda3\envs\virtEnv\lib\site-packages\umap\plot.py:204: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "_nhood_compare" failed type inference due to: Use of unsupported NumPy function 'numpy.intersect1d' or unsupported use of the function.
#
# File "..\..\ProgramData\Anaconda3\envs\virtEnv\lib\site-packages\umap\plot.py", line 210:
# def _nhood_compare(indices_left, indices_right):
#     <source elided>
#     for i in range(indices_left.shape[0]):
#         intersection_size = np.intersect1d(indices_left[i], indices_right[i]).shape[0]
#         ^
#
# [1] During: typing of get attribute at C:\ProgramData\Anaconda3\envs\virtEnv\lib\site-packages\umap\plot.py (210)
#
# File "..\..\ProgramData\Anaconda3\envs\virtEnv\lib\site-packages\umap\plot.py", line 210:
# def _nhood_compare(indices_left, indices_right):
#     <source elided>
#     for i in range(indices_left.shape[0]):
#         intersection_size = np.intersect1d(indices_left[i], indices_right[i]).shape[0]
#         ^
#
#   @numba.jit()
# C:\ProgramData\Anaconda3\envs\virtEnv\lib\site-packages\umap\plot.py:204: NumbaWarning:
# Compilation is falling back to object mode WITHOUT looplifting enabled because Function "_nhood_compare" failed type inference due to: cannot determine Numba type of <class 'numba.core.dispatcher.LiftedLoop'>
#
# File "..\..\ProgramData\Anaconda3\envs\virtEnv\lib\site-packages\umap\plot.py", line 209:
# def _nhood_compare(indices_left, indices_right):
#     <source elided>
#
#     for i in range(indices_left.shape[0]):
#     ^
#
#   @numba.jit()
# C:\ProgramData\Anaconda3\envs\virtEnv\lib\site-packages\numba\core\object_mode_passes.py:178: NumbaWarning: Function "_nhood_compare" was compiled in object mode without forceobj=True, but has lifted loops.
#
# File "..\..\ProgramData\Anaconda3\envs\virtEnv\lib\site-packages\umap\plot.py", line 207:
# def _nhood_compare(indices_left, indices_right):
#     <source elided>
#     """Compute Jaccard index of two neighborhoods"""
#     result = np.empty(indices_left.shape[0])
#     ^
#
#   state.func_ir.loc))
# C:\ProgramData\Anaconda3\envs\virtEnv\lib\site-packages\numba\core\object_mode_passes.py:188: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected, this is deprecated behaviour.
#
# For more information visit http://numba.pydata.org/numba-doc/latest/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "..\..\ProgramData\Anaconda3\envs\virtEnv\lib\site-packages\umap\plot.py", line 207:
# def _nhood_compare(indices_left, indices_right):
#     <source elided>
#     """Compute Jaccard index of two neighborhoods"""
#     result = np.empty(indices_left.shape[0])
#     ^
#
#   state.func_ir.loc))
# C:\ProgramData\Anaconda3\envs\virtEnv\lib\site-packages\umap\plot.py:204: NumbaWarning:
# Compilation is falling back to object mode WITHOUT looplifting enabled because Function "_nhood_compare" failed type inference due to: Use of unsupported NumPy function 'numpy.intersect1d' or unsupported use of the function.
#
# File "..\..\ProgramData\Anaconda3\envs\virtEnv\lib\site-packages\umap\plot.py", line 210:
# def _nhood_compare(indices_left, indices_right):
#     <source elided>
#     for i in range(indices_left.shape[0]):
#         intersection_size = np.intersect1d(indices_left[i], indices_right[i]).shape[0]
#         ^
#
# [1] During: typing of get attribute at C:\ProgramData\Anaconda3\envs\virtEnv\lib\site-packages\umap\plot.py (210)
#
# File "..\..\ProgramData\Anaconda3\envs\virtEnv\lib\site-packages\umap\plot.py", line 210:
# def _nhood_compare(indices_left, indices_right):
#     <source elided>
#     for i in range(indices_left.shape[0]):
#         intersection_size = np.intersect1d(indices_left[i], indices_right[i]).shape[0]
#         ^
#
#   @numba.jit()
# C:\ProgramData\Anaconda3\envs\virtEnv\lib\site-packages\numba\core\object_mode_passes.py:178: NumbaWarning: Function "_nhood_compare" was compiled in object mode without forceobj=True.
#
# File "..\..\ProgramData\Anaconda3\envs\virtEnv\lib\site-packages\umap\plot.py", line 209:
# def _nhood_compare(indices_left, indices_right):
#     <source elided>
#
#     for i in range(indices_left.shape[0]):
#     ^
#
#   state.func_ir.loc))
# C:\ProgramData\Anaconda3\envs\virtEnv\lib\site-packages\numba\core\object_mode_passes.py:188: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected, this is deprecated behaviour.
#
# For more information visit http://numba.pydata.org/numba-doc/latest/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "..\..\ProgramData\Anaconda3\envs\virtEnv\lib\site-packages\umap\plot.py", line 209:
# def _nhood_compare(indices_left, indices_right):
#     <source elided>
#
#     for i in range(indices_left.shape[0]):
#     ^
#
#   state.func_ir.loc))

# %%
#Measure execution time for UMAP
def umapfunc(X):
    model = umap.UMAP(n_neighbors = 40, min_dist = 0.4, n_components = 2)
    umapvar = model.fit_transform(X)
    return umapvar
from timeit import Timer
  
t = Timer(lambda: umapfunc(X_std))
print(t.timeit(number=1))
# Out:
# 5.773883499999997
